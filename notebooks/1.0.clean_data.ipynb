# %% [markdown]
# # Import data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/youtube_data.csv")

# %% [markdown]
# # Data exploration 🔎

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17589 entries, 0 to 17588
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   video_id          17589 non-null  object
#  1   duration          17589 non-null  int64
#  2   bitrate           17589 non-null  int64
#  3   bitrate(video)    17589 non-null  int64
#  4   height            17589 non-null  int64
#  5   width             17589 non-null  int64
#  6   frame rate        17589 non-null  float64
#  7   frame rate(est.)  17589 non-null  float64
#  8   codec             17589 non-null  object
#  9   category          17589 non-null  object
#  10  url               17589 non-null  object
#  11  title             17589 non-null  object
#  12  description       16477 non-null  object
#  13  hashtags          16013 non-null  object
#  14  views             17589 non-null  int64
#  15  likes             17589 non-null  int64
#  16  comments          17589 non-null  int64
# dtypes: float64(2), int64(8), object(7)
# memory usage: 2.3+ MB

# %%
df.dtypes
# Out:
# video_id             object
# duration              int64
# bitrate               int64
# bitrate(video)        int64
# height                int64
# width                 int64
# frame rate          float64
# frame rate(est.)    float64
# codec                object
# category             object
# url                  object
# title                object
# description          object
# hashtags             object
# views                 int64
# likes                 int64
# comments              int64
# dtype: object

# %%
df.describe()
# Out:
#            duration       bitrate  bitrate(video)        height         width  \
# count  17589.000000  17589.000000    17589.000000  17589.000000  17589.000000
# mean     241.551936   1271.354369     1150.418443    766.781170    504.591961
# std      493.026994   1375.359875     1351.800202    467.289304    262.727746
# min        1.000000      0.000000        0.000000    108.000000     88.000000
# 25%       51.000000    437.000000      326.000000    426.000000    320.000000
# 50%      135.000000    743.000000      632.000000    640.000000    480.000000
# 75%      268.000000   1293.000000     1184.000000    960.000000    720.000000
# max    25845.000000  22421.000000    22229.000000   2592.000000   1944.000000
#
#          frame rate  frame rate(est.)         views          likes  \
# count  17589.000000      17589.000000  1.758900e+04   17589.000000
# mean      26.467639          9.471172  6.894158e+04     208.862641
# std        6.039748         13.253197  3.537491e+06    8477.504735
# min        3.750000          0.000000  0.000000e+00       0.000000
# 25%       25.000000          0.000000  3.800000e+01       0.000000
# 50%       29.970000          0.000000  1.520000e+02       1.000000
# 75%       29.970000         25.000000  8.000000e+02       4.000000
# max       59.080000         30.000000  4.103849e+08  836981.000000
#
#            comments
# count  17589.000000
# mean      12.899312
# std      225.839378
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max    16634.000000

# %%
print(df.shape)
print(df.columns)
# Out:
# (17589, 17)
# Index(['video_id', 'duration', 'bitrate', 'bitrate(video)', 'height', 'width',
#        'frame rate', 'frame rate(est.)', 'codec', 'category', 'url', 'title',
#        'description', 'hashtags', 'views', 'likes', 'comments'],
#       dtype='object')

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#           video_id  duration  bitrate  bitrate(video)  height  width  \
# 0      --F7dc-_FSI       180     5777            5640    1920   1080
# 1      --cCAD-8Y_U       930     1195            1001    1280    720
# 2      --g2gG8pQ0w       233     3028            2833    1280    720
# 3      -0DR7-voRCU       562      431             300     320    240
# 4      -0Fkp-2EzX0       300     3087            2929    1280    720
# ...            ...       ...      ...             ...     ...    ...
# 17584  zyK7-WQTDaY       571     1285            1175     640    480
# 17585  zyPO-hxvWDg       105      840             719     640    480
# 17586  zyYk-W_JqNY       161      920             820     640    480
# 17587  zz3a-wnxBrs       291     4892            4738    1920   1080
# 17588  zzF2-Z2B5Wc       244      392             302     320    240
#
#        frame rate  frame rate(est.) codec         category  \
# 0           25.00             25.00  h264  News & Politics
# 1           30.00             30.00  h264           Gaming
# 2           23.98             23.98  h264           Comedy
# 3           29.97              0.00  h264   People & Blogs
# 4           23.98             23.98  h264           Gaming
# ...           ...               ...   ...              ...
# 17584       29.92              0.00  h264   People & Blogs
# 17585       29.97              0.00  h264   People & Blogs
# 17586       29.97              0.00  h264   People & Blogs
# 17587       29.97             29.97  h264           Gaming
# 17588       25.00              0.00  h264   People & Blogs
#
#                                                url  \
# 0      https://www.youtube.com/watch?v=--F7dc-_FSI
# 1      https://www.youtube.com/watch?v=--cCAD-8Y_U
# 2      https://www.youtube.com/watch?v=--g2gG8pQ0w
# 3      https://www.youtube.com/watch?v=-0DR7-voRCU
# 4      https://www.youtube.com/watch?v=-0Fkp-2EzX0
# ...                                            ...
# 17584  https://www.youtube.com/watch?v=zyK7-WQTDaY
# 17585  https://www.youtube.com/watch?v=zyPO-hxvWDg
# 17586  https://www.youtube.com/watch?v=zyYk-W_JqNY
# 17587  https://www.youtube.com/watch?v=zz3a-wnxBrs
# 17588  https://www.youtube.com/watch?v=zzF2-Z2B5Wc
#
#                                                    title  \
# 0                  «السودان ينتفض» أمام السفارة بالقاهرة
# 1                     Pokemon Tower Defense   Episodio 2
# 2                   New Hip Hop - Kemo Treats - Pancakes
# 3                             Sister's Keeper Impression
# 4      JBHAMMER777 (AKUMA) VS KtossPol  Rank 1 (Vega)...
# ...                                                  ...
# 17584                             rentero 1ª parte 2.MOD
# 17585  Cascavel faz campanha impecável em campeonato ...
# 17586  Marcha para Cristo.San Francisco Menéndez.  5 ...
# 17587                             DK Solo Steinerne Kern
# 17588  &#x202b;يارب نور دربي لعبد المجيد الفوزان بجود...
#
#                                              description  \
# 0      حرية سلام وعدالة، الثورة خيار الشعب.. بهذا اله...
# 1                    Espero que tenham gostado do video!
# 2      Download all our music for FREE just enter $0....
# 3      A Review of the Shampoo Bar(Sunburst) and Dip ...
# 4      JBHAMMER777 is he strong enough to fight again...
# ...                                                  ...
# 17584
# 17585
# 17586                                                NaN
# 17587  Das ist mein erstes Video, also ist noch alles...
# 17588
#
#                                                 hashtags  views  likes  \
# 0      في, عسكري, حكم, حرية, بخصوص, المصري اليوم, الس...   4078     41
# 1      Pokémon (Anime/Manga Franchise), Pokémon (Vide...     33      2
# 2      breaking bad spoof, Recipes, Pancakes, canada,...  13227    135
# 3      natural hair, first impression, sister's keepe...     43      1
# 4      Tokido, momochi, (Ryu), AE, 11, at, Piyoppia, ...    222      2
# ...                                                  ...    ...    ...
# 17584                   rentero, latapialinares, iu, pca     27      0
# 17585                                                NaN    295      1
# 17586                               Cristo, Marcha, para    770      3
# 17587  Steinerne Kern, Vitriolsteindrachen, DK Solo, ...     42      1
# 17588  نور, بجوده, دربي, &#x202b;يارب, المجيد, عاليه&...     20      0
#
#        comments
# 0             3
# 1             1
# 2            17
# 3             0
# 4             0
# ...         ...
# 17584         0
# 17585         0
# 17586         0
# 17587         0
# 17588         0
#
# [17589 rows x 17 columns]

# %%
drop_cols = ['video_id', 'url']
df = df.drop(columns=drop_cols)

# %% [markdown]
# # Sắp xếp dữ liệu

# %% [markdown]
# ## Xử lí giá trị bị khuyết

# %%
print(df.isnull().sum())
missing_percent = 100 * df.isnull().sum() / len(df)

print(missing_percent)
# Out:
# duration               0
# bitrate                0
# bitrate(video)         0
# height                 0
# width                  0
# frame rate             0
# frame rate(est.)       0
# codec                  0
# category               0
# title                  0
# description         1112
# hashtags            1576
# views                  0
# likes                  0
# comments               0
# dtype: int64
# duration            0.000000
# bitrate             0.000000
# bitrate(video)      0.000000
# height              0.000000
# width               0.000000
# frame rate          0.000000
# frame rate(est.)    0.000000
# codec               0.000000
# category            0.000000
# title               0.000000
# description         6.322133
# hashtags            8.960146
# views               0.000000
# likes               0.000000
# comments            0.000000
# dtype: float64

# %% [markdown]
# Check các cột nghi ngờ cho giá trị null ẩn không thể kiểm tra bằng isnull()

# %%
def check_hidden_missing(df):
    suspected = ['?', '.', 'N/A', 'NA', 'NaN', 'nan', 'NULL', 'Null', 'None', ' ', '', '0']
    result = {}

    for col in df.columns:
        mask = df[col].astype(str).isin(suspected) | df[col].astype(str).str.strip().eq('')
        result[col] = mask.sum()

    result_df = pd.DataFrame.from_dict(result, orient='index', columns=['Suspected Missing'])
    result_df['Percentage (%)'] = 100 * result_df['Suspected Missing'] / len(df)

    return result_df[result_df['Suspected Missing'] > 0].sort_values('Percentage (%)', ascending=False)

hidden_missing_table = check_hidden_missing(df)
hidden_missing_table
# Out:
#                 Suspected Missing  Percentage (%)
# comments                    12899       73.335607
# likes                        7918       45.016772
# description                  4262       24.231053
# hashtags                     1577        8.965831
# views                         171        0.972199
# bitrate(video)                122        0.693615
# bitrate                         3        0.017056
# title                           1        0.005685

# %%
df.loc[df['bitrate(video)'] == 0, ['duration', 'width', 'height', 'views']].head(10)
# Out:
#       duration  width  height    views
# 66        1908    226     400       49
# 164        233    240     320  2493956
# 165         98    240     320       84
# 258        515    480     640   247954
# 305        418    480     640       15
# 541         76    320     568     1116
# 838         86    120     174        7
# 1489        78    240     320       15
# 1521        39    480     640      441
# 1887        69    480     640      839

# %%
df.loc[df['bitrate'] == 0, 'bitrate'] = np.nan
df.loc[df['bitrate(video)'] == 0, 'bitrate(video)'] = np.nan

# %%
suspected_missing = ['?', '.', 'N/A', 'NA', 'NaN', 'nan', 'NULL', 'Null', 'None', ' ', '']

# Chuẩn hóa các giá trị nghi ngờ thành NaN
df['description'].replace(suspected_missing, np.nan, inplace=True)
df['hashtags'].replace(suspected_missing, np.nan, inplace=True)

# Điền lại bằng giá trị thay thế có ý nghĩa
df['description'].fillna('No description', inplace=True)
df['hashtags'].fillna('No hashtags', inplace=True)
# Out:
# /var/folders/06/55ncynjj69l30_gnnsnw6xv40000gn/T/ipykernel_22407/3776434866.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['description'].replace(suspected_missing, np.nan, inplace=True)
# /var/folders/06/55ncynjj69l30_gnnsnw6xv40000gn/T/ipykernel_22407/3776434866.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['hashtags'].replace(suspected_missing, np.nan, inplace=True)

# %%
df.isnull().sum()
# Out:
# duration              0
# bitrate               3
# bitrate(video)      122
# height                0
# width                 0
# frame rate            0
# frame rate(est.)      0
# codec                 0
# category              0
# title                 0
# description           0
# hashtags              0
# views                 0
# likes                 0
# comments              0
# dtype: int64

# %% [markdown]
# ## Điền khuyết

# %%
df_drop = df.copy()
df_fill_median = df.copy()
df_fill_mean = df.copy()

# %%
df_drop.dropna(subset=['bitrate', 'bitrate(video)'], inplace=True)

df_fill_median['bitrate'].fillna(df_fill_median['bitrate'].median(), inplace=True)
df_fill_median['bitrate(video)'].fillna(df_fill_median['bitrate(video)'].median(), inplace=True)

df_fill_mean['bitrate'].fillna(df_fill_mean['bitrate'].mean(), inplace=True)
df_fill_mean['bitrate(video)'].fillna(df_fill_mean['bitrate(video)'].mean(), inplace=True)
# Out:
# /var/folders/06/55ncynjj69l30_gnnsnw6xv40000gn/T/ipykernel_22407/1752373119.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fill_median['bitrate'].fillna(df_fill_median['bitrate'].median(), inplace=True)
# /var/folders/06/55ncynjj69l30_gnnsnw6xv40000gn/T/ipykernel_22407/1752373119.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fill_median['bitrate(video)'].fillna(df_fill_median['bitrate(video)'].median(), inplace=True)
# /var/folders/06/55ncynjj69l30_gnnsnw6xv40000gn/T/ipykernel_22407/1752373119.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fill_mean['bitrate'].fillna(df_fill_mean['bitrate'].mean(), inplace=True)
# /var/folders/06/55ncynjj69l30_gnnsnw6xv40000gn/T/ipykernel_22407/1752373119.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fill_mean['bitrate(video)'].fillna(df_fill_mean['bitrate(video)'].mean(), inplace=True)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# bitrate
sns.kdeplot(df_drop['bitrate'], label='Dropped NaN', ax=axes[0])
sns.kdeplot(df_fill_median['bitrate'], label='Filled Median', ax=axes[0])
sns.kdeplot(df_fill_mean['bitrate'], label='Filled Mean', ax=axes[0])
axes[0].set_title('Distribution Comparison: bitrate')
axes[0].legend()

# bitrate(video)
sns.kdeplot(df_drop['bitrate(video)'], label='Dropped NaN', ax=axes[1])
sns.kdeplot(df_fill_median['bitrate(video)'], label='Filled Median', ax=axes[1])
sns.kdeplot(df_fill_mean['bitrate(video)'], label='Filled Mean', ax=axes[1])
axes[1].set_title('Distribution Comparison: bitrate(video)')
axes[1].legend()

plt.show()

# %% [markdown]
# 3 đường kde đè lên nhau -> ảnh hưởng shape phân phối là như

# %%
compare = pd.DataFrame({
    'Method': ['Dropped', 'Filled Median', 'Filled Mean'],
    'bitrate_mean': [df_drop['bitrate'].mean(), df_fill_median['bitrate'].mean(), df_fill_mean['bitrate'].mean()],
    'bitrate_std': [df_drop['bitrate'].std(), df_fill_median['bitrate'].std(), df_fill_mean['bitrate'].std()],
    'bitrate(video)_mean': [df_drop['bitrate(video)'].mean(), df_fill_median['bitrate(video)'].mean(), df_fill_mean['bitrate(video)'].mean()],
    'bitrate(video)_std': [df_drop['bitrate(video)'].std(), df_fill_median['bitrate(video)'].std(), df_fill_mean['bitrate(video)'].std()]
})
compare
# Out:
#           Method  bitrate_mean  bitrate_std  bitrate(video)_mean  \
# 0        Dropped   1272.999084  1376.581154          1158.453655
# 1  Filled Median   1271.481181  1375.276916          1154.850645
# 2    Filled Mean   1271.571250  1375.259626          1158.453655
#
#    bitrate(video)_std
# 0         1353.077591
# 1         1349.065649
# 2         1348.376581

# %% [markdown]
# bitrate_std và birate(video)_std gần như là như nhau ở cả 3 method -> độ phân tán giống nhau => phương án loại bỏ các bản ghi bị khuyết (Dropped) vì tỷ lệ thiếu nhỏ (<1%) và đảm bảo giữ nguyên phân phối tự nhiên của dữ liệu.

# %%
df['bitrate'].fillna(df['bitrate'].median(), inplace=True)
df['bitrate(video)'].fillna(df['bitrate(video)'].median(), inplace=True)
# Out:
# /var/folders/06/55ncynjj69l30_gnnsnw6xv40000gn/T/ipykernel_22407/1107592977.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bitrate'].fillna(df['bitrate'].median(), inplace=True)
# /var/folders/06/55ncynjj69l30_gnnsnw6xv40000gn/T/ipykernel_22407/1107592977.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bitrate(video)'].fillna(df['bitrate(video)'].median(), inplace=True)

# %%
hidden_missing_table = check_hidden_missing(df)
hidden_missing_table
# Out:
#           Suspected Missing  Percentage (%)
# comments              12899       73.335607
# likes                  7918       45.016772
# views                   171        0.972199
# title                     1        0.005685

# %%
df = df[~df['title'].astype(str).str.strip().eq('')]

# %%
check_raw = df[
    (df['views'].astype(float) == 0) &
    (
        (df['likes'].astype(float) > 0) |
        (df['comments'].astype(float) > 0)
    )
]

print("Số dòng bất thường:", len(check_raw))
check_raw
# Out:
# Số dòng bất thường: 2
#        duration  bitrate  bitrate(video)  height  width  frame rate  \
# 7403       2995    485.0           355.0     854    480        30.0
# 15586       640    463.0           333.0     854    480        30.0
#
#        frame rate(est.) codec       category  \
# 7403                0.0  h264  Entertainment
# 15586               0.0  h264  Entertainment
#
#                                                    title  \
# 7403   Misha4Pats: Podcast: Episode 2: The Mattrick H...
# 15586                     Sortegi Europa League (Ottavi)
#
#                                              description  \
# 7403   Misha4Pats: Podcast: Episode 2: The Mattrick H...
# 15586  Sortegi Europa League (Ottavi) Chiedo Venia pe...
#
#                                     hashtags  views  likes  comments
# 7403   #hoa, #hangoutsonair, Hangouts On Air      0      1         0
# 15586  #hoa, #hangoutsonair, Hangouts On Air      0      1         0

# %% [markdown]
# 2 dòng có views = 0 nhưng lại có likes > 0

# %%
df = df.drop(check_raw.index)

# %%
hidden_missing_table = check_hidden_missing(df)
hidden_missing_table
# Out:
#           Suspected Missing  Percentage (%)
# comments              12896       73.331059
# likes                  7917       45.018765
# views                   169        0.960992

# %% [markdown]
# 3 cột views, likes, comments, có nhiều giá trị 0 không được coi là nhiều missing values, vì nó thể hiện đúng bản chất của youtube videos, có thể có lượt xem hoặc không có lượt xem, cũng như lượt likes và bình luận

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# ## Định dạng dữ liệu

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17586 entries, 0 to 17585
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   duration          17586 non-null  int64
#  1   bitrate           17586 non-null  float64
#  2   bitrate(video)    17586 non-null  float64
#  3   height            17586 non-null  int64
#  4   width             17586 non-null  int64
#  5   frame rate        17586 non-null  float64
#  6   frame rate(est.)  17586 non-null  float64
#  7   codec             17586 non-null  object
#  8   category          17586 non-null  object
#  9   title             17586 non-null  object
#  10  description       17586 non-null  object
#  11  hashtags          17586 non-null  object
#  12  views             17586 non-null  int64
#  13  likes             17586 non-null  int64
#  14  comments          17586 non-null  int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Tất cả các cột đều có giá trị hợp lệ, không còn dữ liệu khuyết.

# %% [markdown]
# ## Chuẩn bị data cho các stages tiếp theo

# %%
df.to_csv("../data/youtube_clean.csv", index=False, encoding="utf-8")

df_cleaned = pd.read_csv("../data/youtube_clean.csv")

# %%
df_cleaned
# Out:
#        duration  bitrate  bitrate(video)  height  width  frame rate  \
# 0           180   5777.0          5640.0    1920   1080       25.00
# 1           930   1195.0          1001.0    1280    720       30.00
# 2           233   3028.0          2833.0    1280    720       23.98
# 3           562    431.0           300.0     320    240       29.97
# 4           300   3087.0          2929.0    1280    720       23.98
# ...         ...      ...             ...     ...    ...         ...
# 17581       571   1285.0          1175.0     640    480       29.92
# 17582       105    840.0           719.0     640    480       29.97
# 17583       161    920.0           820.0     640    480       29.97
# 17584       291   4892.0          4738.0    1920   1080       29.97
# 17585       244    392.0           302.0     320    240       25.00
#
#        frame rate(est.) codec         category  \
# 0                 25.00  h264  News & Politics
# 1                 30.00  h264           Gaming
# 2                 23.98  h264           Comedy
# 3                  0.00  h264   People & Blogs
# 4                 23.98  h264           Gaming
# ...                 ...   ...              ...
# 17581              0.00  h264   People & Blogs
# 17582              0.00  h264   People & Blogs
# 17583              0.00  h264   People & Blogs
# 17584             29.97  h264           Gaming
# 17585              0.00  h264   People & Blogs
#
#                                                    title  \
# 0                  «السودان ينتفض» أمام السفارة بالقاهرة
# 1                     Pokemon Tower Defense   Episodio 2
# 2                   New Hip Hop - Kemo Treats - Pancakes
# 3                             Sister's Keeper Impression
# 4      JBHAMMER777 (AKUMA) VS KtossPol  Rank 1 (Vega)...
# ...                                                  ...
# 17581                             rentero 1ª parte 2.MOD
# 17582  Cascavel faz campanha impecável em campeonato ...
# 17583  Marcha para Cristo.San Francisco Menéndez.  5 ...
# 17584                             DK Solo Steinerne Kern
# 17585  &#x202b;يارب نور دربي لعبد المجيد الفوزان بجود...
#
#                                              description  \
# 0      حرية سلام وعدالة، الثورة خيار الشعب.. بهذا اله...
# 1                    Espero que tenham gostado do video!
# 2      Download all our music for FREE just enter $0....
# 3      A Review of the Shampoo Bar(Sunburst) and Dip ...
# 4      JBHAMMER777 is he strong enough to fight again...
# ...                                                  ...
# 17581                                     No description
# 17582                                     No description
# 17583                                     No description
# 17584  Das ist mein erstes Video, also ist noch alles...
# 17585                                     No description
#
#                                                 hashtags  views  likes  \
# 0      في, عسكري, حكم, حرية, بخصوص, المصري اليوم, الس...   4078     41
# 1      Pokémon (Anime/Manga Franchise), Pokémon (Vide...     33      2
# 2      breaking bad spoof, Recipes, Pancakes, canada,...  13227    135
# 3      natural hair, first impression, sister's keepe...     43      1
# 4      Tokido, momochi, (Ryu), AE, 11, at, Piyoppia, ...    222      2
# ...                                                  ...    ...    ...
# 17581                   rentero, latapialinares, iu, pca     27      0
# 17582                                        No hashtags    295      1
# 17583                               Cristo, Marcha, para    770      3
# 17584  Steinerne Kern, Vitriolsteindrachen, DK Solo, ...     42      1
# 17585  نور, بجوده, دربي, &#x202b;يارب, المجيد, عاليه&...     20      0
#
#        comments
# 0             3
# 1             1
# 2            17
# 3             0
# 4             0
# ...         ...
# 17581         0
# 17582         0
# 17583         0
# 17584         0
# 17585         0
#
# [17586 rows x 15 columns]
